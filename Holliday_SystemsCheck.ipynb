# %% [markdown]
# # Andre Holliday

# %% [markdown]
# ## Things I Want to Learn From This Class

# %% [markdown]
# 1. Learn how to analyze data.
# 2. Improve my Python skills.
# 3. Learn how data can be used in emerging media.
# 4. Develop skills I can use in my future career.

# %% [markdown]
# **Kent State Emat**

# %% [markdown]
# *Class of 2027*

# %% [markdown]
# ![Kent State Logo](attachment:d931f851-216a-45a8-bbbd-eb7862524cbb.jpg)
